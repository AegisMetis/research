# %% [markdown]
# ## Visualización básica com matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
years = [2020, 2021, 2022]
values = [5, 8, 12]

# %%
plt.plot(years, values);

# %%
plt.scatter(years, values);

# %% [markdown]
# Visualizar la evolución de la cotización en bolsa del índice SP500

# %%
df_sp500 = pd.read_csv(r'C:\Proyectos-FJCH\Udemy\data-science-con-python-numpy-pandas\data\1.4\SP500_data.csv') # Delimitador por defecto ','

# %%
df_sp500
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23186  2020-04-23  2810.419922  2844.899902  2794.260010  2797.800049
# 23187  2020-04-24  2812.639893  2842.709961  2791.760010  2836.739990
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
#
#          Adj Close      Volume
# 0        17.660000           0
# 1        17.760000           0
# ...

# %%
df_sp500.set_index('Date', inplace=True)

# %%
df_sp500.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000       0
# 1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999       0
# 1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999       0
# 1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000       0

# %%
df_sp500['Close'].plot(); # Se puede hacer directamente sobre el DataFrame con la función plot()
